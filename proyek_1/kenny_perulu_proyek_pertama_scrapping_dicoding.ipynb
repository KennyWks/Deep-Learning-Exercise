# %% [markdown]
# Scrapping Review APK Discord by Google Play Store

# %% [markdown]
# # Install Modules

# %%
# !pip install google-play-scraper
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Scraping Dataset

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all

# Mengambil review dari aplikasi dengan ID 'com.discord'.
scrapreview = reviews_all(
    'com.discord',         # ID aplikasi
    lang='id',             # Bahasa : id
    country='id',          # Negaara : id
    sort=Sort.MOST_RELEVANT, # Urutan review berdasarkan relevansi
    count=1000             # Jumlah maksimum ulasan yang diambil
)

# %%
# Menyimpan review ke dalam file CSV
import csv
 
with open('ulasan_aplikasi_discord.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten review ke dalam file CSV

# %%
import pandas as pd  # Pandas untuk manipulasi dan analisis data
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining

app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi_discord.csv', index=False)
 
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)
 
# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan data di dalam DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  cf0348fe-ceca-4a51-8bcd-fa560d7748f6  Pengguna Google
# 1  2a6060d9-d1b9-49b3-86bf-8416d172f4a4  Pengguna Google
# 2  e4e424d2-76f2-4755-9cc8-58ec8555a0a4  Pengguna Google
# 3  b14c042c-1128-4b1d-9f81-d1908100adb3  Pengguna Google
# 4  7905abc8-f072-49cb-9ffa-4e8e937b6f77  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Di handphone saya lagi error temen temen lgi v...      3              5
# 1  Udah cukup lama pakai Discord dan sampai sekar...      5              4
# ...

# %%
# Menampilkan informasi DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 70496 entries, 0 to 70495
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              70496 non-null  str
#  1   userName              70496 non-null  str
#  2   userImage             70496 non-null  str
#  3   content               70495 non-null  str
#  4   score                 70496 non-null  int64
#  5   thumbsUpCount         70496 non-null  int64
#  6   reviewCreatedVersion  44570 non-null  str
#  7   at                    70496 non-null  datetime64[us]
#  8   replyContent          17852 non-null  str
#  9   repliedAt             17852 non-null  datetime64[us]
#  10  appVersion            44570 non-null  str
# dtypes: datetime64[us](2), int64(2), str(7)
# memory usage: 25.8 MB
